# %% [markdown]
# # Numerically Solving the Lane-Emden equation
# After the lecture 1, we are going to explore the solutions with different polytropic indexes. We want to make a function that generates the solutions to the Lane-Emden equation as a function of polytropic index.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def solution_Lane_Emden(n, h=0.001, save_to_path=None):
    """
    Compute the solutions to Lane-Emden equation.
    
    Parameters
    ----------
    n            : float
                   polytropic index
           
    Optional Parameters
    -------------------
    h            : float
                   step of the numerical integral. default = 0.001
    save_to_path : str
                   the path to save the plot. default = None
           
    
    Returns
    -------
    xi_array     : 1d numpy array
                   xi as a step of h to the point where rho goes to zero
    D_array      : 1d numpy array
                   D as a function of xi
           
    """
    ## set the initial parameters
    ## you can define xi, D, f, and lists to store the elements
    # your code here

    # use while or for loops to solve for the Lane-Emden equation
    # You can separate general n except for n = 0 and n = 5
    if (n != 0.0) and (n != 5.0):
        # your code here
    elif n == 0.0:
        # your code here
    elif n == 5.0:
        # your code here


    ## generate the plot here
    plt.figure(figsize=(8,8))
    plt.plot(xi_list, D_list)
    plt.minorticks_on()
    plt.title('n={}'.format(n), fontsize=20)
    plt.xlabel(r'$\xi$', fontsize=20)
    plt.ylabel(r'$\theta_n(\xi)$', fontsize=20)
    if save_to_path is not None:
        plt.savefig(save_to_path+'n{}.png'.format(10*n))
    plt.show()
    plt.close()
    
    
    return np.array(xi_list), np.array(D_list)

# %% [markdown]
# Run the cases for n = 1.5 and n = 3.0

# %%
xi30, D30 = solution_Lane_Emden(n=3.0)
# Out:
# The solution to n=3.0: 6.894000000000637 with dD/dxi  = -0.042426421546253826

# %%
xi15, D15 = solution_Lane_Emden(n=1.5)
# Out:
# The solution to n=1.5: 3.651999999999709 with dD/dxi  = -0.20339376660572953

# %% [markdown]
# You can combine different solutions together and compare

# %%
## Your code here; you can refer to the plotting code in the function above

# %% [markdown]
# You can also generate the solutions for other polytropic indexes. Try n = 0, 1, 5, in which they all have analytic solutions and compare them in the plot.

# %%
xi00, D00 = solution_Lane_Emden(n=0.0)
# Out:
# The solution to n=0.0: 2.449999999999841 with dD/dxi  = 0

# %%
xi10, D10 = solution_Lane_Emden(n=1.0)
# Out:
# The solution to n=1.0: 3.140999999999765 with dD/dxi  = -0.318332937268531

# %% [markdown]
# Compare the solutions for n = 4.9 and n = 5.0

# %%
xi49, D49 = solution_Lane_Emden(n=4.9) # use 4.9 to approximate 5.0
# Out:
# The solution to n=4.9: 173.836000000466 with dD/dxi  = -5.701610230323087e-05

# %%
xi50, D50 = solution_Lane_Emden(n=5.0)
# Out:
# The solution to n=5.0: 173.19700000046294 with dD/dxi  = 0

# %% [markdown]
# compare all outputs of theta here as a function of xi

# %%
## Your code here

# %% [markdown]
# You can also normalize them to see how concentrated each polytrope is

# %%
## your code here

# %% [markdown]
# Congratuations! You just made a numerical solver for the Lane-Emdem equation.
